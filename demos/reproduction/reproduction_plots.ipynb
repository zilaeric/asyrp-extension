# %% [markdown]
# ## Plots for "Reproduction of the Experiments"

# %%
import sys
sys.path.append('../../src/lib/utils/')

import plots

# %%
plots.reproduction_in([61, 62, 71], ["woman", "man", "woman"])

# %%
plots.reproduction_in([61, 62, 71], ["woman", "man", "woman"], 1.0)

# %%
plots.reproduction_unseen([26, 27, 28])

# %%
plots.reproduction_unseen([26, 27, 28], 1.0)

# %%
plots.reproduction_linearity(99)

# %%
plots.reproduction_details(range(20, 25))
